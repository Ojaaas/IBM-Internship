# %% [markdown]
# # Homework 1
#
# Run the code cell below before starting.

# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %% [markdown]
# ### Part 1
#
# Create a pandas dataframe from the search_sample.txt file provided.

# %%
# Update file path to search sample
search_df = pd.read_json('search_sample.txt', lines=True)

# %% [markdown]
# ### Part 2
#
# Display the top rows of the dataframe.

# %%
search_df.head(search_df.shape[0])
# Out:
#                     timestamp                             requestid  appid  \
# 0     2021-07-11 14:53:10.788  c65647a8-bb47-45bd-8ffe-628fd7092c95    its
# 1     2021-07-11 14:53:10.967  3826f01e-0548-411d-9d29-5b3735a4e1b5  dblue
# 2     2021-07-11 14:53:11.247  d05b7ac0-897b-4a54-9947-397f75554e15    its
# 3     2021-07-11 14:53:11.647  a2d31daf-31be-437d-b587-d7fa31aed884     dw
# 4     2021-07-11 14:53:11.915  592f79eb-90f8-4647-8178-b95d360bd23e    its
# ...                       ...                                   ...    ...
# 19994 2021-07-11 16:37:09.454  03c9d866-8a6a-4cba-9e35-6d828778d2d9    its
# 19995 2021-07-11 16:37:10.170  b5f25388-1b68-4291-8b68-ea663a13f93e    its
# 19996 2021-07-11 16:37:10.502  2d1ce1c5-d77e-4834-8f35-8f711e83e942  dblue
# 19997 2021-07-11 16:37:11.214  e56cda91-28bb-499b-b841-6d7b5df443b6    its
# 19998 2021-07-11 16:37:11.475  ddadf01c-af8c-4d08-956f-b68c9cdfee77  dblue
#
# ...
